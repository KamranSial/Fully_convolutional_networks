# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.cm as cm
import copy
import tensorflow as tf
import Image
import os
import time
import numpy as np
from IPython.display import clear_output
import sys
import csv
import math
from matplotlib import colors
import fcn32_new_wval as fcn32_vgg
import csv
TRAINSET_PATH1 = '/mnt/data3/Game_data/csv_files/gamedata_val2.csv'
train_csv_file=open(TRAINSET_PATH1,"r")
train_filepaths=[]
train_labels=[]
train_masks=[]
for line in train_csv_file:
    filepath, label, mask= line.split(",")
    train_filepaths.append(filepath)
    train_labels.append(label)
    train_masks.append(mask.split("\r")[0])
    
filenames=os.listdir("/mnt/data3/Game_data/train/images/")
path="/mnt/data3/Game_data/train/images/"
path2="/mnt/data3/Game_data/train/classes/"

nump=0
for i in xrange(len(train_filepaths)):
    img= Image.open(train_filepaths[i]).size
    #img=np.array(img)
    img2= Image.open(train_labels[i]).size
    #img2=np.array(img2)
    #if not (len(img)==1052 and len(img[0]==1914)):
    #print(img[0],img[1])
    print(img2[0],img2[1])
    nump+=1
    
print(nump)
# Out:
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# (1914, 1046)
# ...
